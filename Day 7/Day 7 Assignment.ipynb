# %% [markdown]
# ## loading the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## loading the dataset

# %%
dataset = pd.read_csv("general_data.csv")

# %%
dataset.head(10)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
# 5   46        No      Travel_Rarely  Research & Development                 8
# 6   28       Yes      Travel_Rarely  Research & Development                11
# 7   29        No      Travel_Rarely  Research & Development                18
# 8   31        No      Travel_Rarely  Research & Development                 1
# 9   25        No         Non-Travel  Research & Development                 7
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  \
# ...

# %% [markdown]
# ## seeing the columns

# %%
dataset.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ### checking for null values

# %%
dataset.isnull()
# Out:
#         Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0     False      False           False       False             False
# 1     False      False           False       False             False
# 2     False      False           False       False             False
# 3     False      False           False       False             False
# 4     False      False           False       False             False
# 5     False      False           False       False             False
# 6     False      False           False       False             False
# 7     False      False           False       False             False
# 8     False      False           False       False             False
# 9     False      False           False       False             False
# 10    False      False           False       False             False
# 11    False      False           False       False             False
# 12    False      False           False       False             False
# ...

# %% [markdown]
# ### checking for duplicate values

# %%
dataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 4380    False
# 4381    False
# 4382    False
# 4383    False
# 4384    False
# 4385    False
# 4386    False
# 4387    False
# 4388    False
# 4389    False
# 4390    False
# 4391    False
# 4392    False
# 4393    False
# 4394    False
# 4395    False
# 4396    False
# 4397    False
# 4398    False
# 4399    False
# 4400    False
# 4401    False
# 4402    False
# 4403    False
# 4404    False
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# ...

# %% [markdown]
# ### univariate analysis: basic information about data

# %%
dataset.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %% [markdown]
# ### median of some continuos variables

# %%
medians = dataset[['Age', 'DistanceFromHome', 'Education', 'MonthlyIncome', 'PercentSalaryHike', 'TotalWorkingYears']].median()

# %%
medians
# Out:
# Age                     36.0
# DistanceFromHome         7.0
# Education                3.0
# MonthlyIncome        49190.0
# PercentSalaryHike       14.0
# TotalWorkingYears       10.0
# dtype: float64

# %%
variances = dataset[['Age', 'DistanceFromHome', 'Education', 'MonthlyIncome', 'PercentSalaryHike', 'TotalWorkingYears']].var()

# %%
variances
# Out:
# Age                  8.341719e+01
# DistanceFromHome     6.569144e+01
# Education            1.048438e+00
# MonthlyIncome        2.215480e+09
# PercentSalaryHike    1.338907e+01
# TotalWorkingYears    6.056298e+01
# dtype: float64

# %%
skewedness = dataset[['Age', 'DistanceFromHome', 'Education', 'MonthlyIncome', 'PercentSalaryHike', 'TotalWorkingYears']].skew()

# %%
skewedness
# Out:
# Age                  0.413005
# DistanceFromHome     0.957466
# Education           -0.289484
# MonthlyIncome        1.368884
# PercentSalaryHike    0.820569
# TotalWorkingYears    1.116832
# dtype: float64

# %% [markdown]
# ## Inference: all variables except education have positive skewedness

# %%
kurtosis = dataset[['Age', 'DistanceFromHome', 'Education', 'MonthlyIncome', 'PercentSalaryHike', 'TotalWorkingYears']].kurt()

# %%
kurtosis
# Out:
# Age                 -0.405951
# DistanceFromHome    -0.227045
# Education           -0.560569
# MonthlyIncome        1.000232
# PercentSalaryHike   -0.302638
# TotalWorkingYears    0.912936
# dtype: float64

# %% [markdown]
# ### Detecting outliers

# %%
plt.boxplot(dataset.Age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22dc5de8978>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22dc5de8e80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22dc5de8400>],
#  'medians': [<matplotlib.lines.Line2D at 0x22dc5df9a58>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22dc5df9e80>],
#  'means': []}

# %% [markdown]
# ### Inference: age is normally distributed without any outliers

# %%
plt.boxplot(dataset.MonthlyIncome)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22dc5a54fd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22dc5f73fd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22dc5f73278>],
#  'medians': [<matplotlib.lines.Line2D at 0x22dc5f7b860>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22dc5f7bc88>],
#  'means': []}

# %% [markdown]
# ## Inference: right skewed with several outliers

# %%
plt.boxplot(dataset.YearsAtCompany)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22dc6253780>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22dc6253fd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22dc6253240>],
#  'medians': [<matplotlib.lines.Line2D at 0x22dc625f860>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22dc625fc88>],
#  'means': []}

# %% [markdown]
# ### Inference: right skewed with several outliers

# %% [markdown]
# ## Performing statistical testings

# %%
dataset = pd.read_csv("general_data.csv")
dataset.head()
print(dataset['Attrition'].dtype)
# Out:
# object

# %% [markdown]
# ### attrition: with respect to distance from home

# %%
from scipy.stats import pearsonr

# %%
print(dataset['Attrition'].dtype)
dataset['Attrition'] = dataset['Attrition'].apply(lambda x: 1.0 if x == 'Yes' else 0.0)
dataset['Attrition'].head()
dataset.head()
# Out:
# object
#    Age  Attrition     BusinessTravel              Department  \
# 0   51        0.0      Travel_Rarely                   Sales
# 1   31        1.0  Travel_Frequently  Research & Development
# 2   32        0.0  Travel_Frequently  Research & Development
# 3   38        0.0         Non-Travel  Research & Development
# 4   32        0.0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
#
#    Gender          ...           NumCompaniesWorked Over18 PercentSalaryHike  \
# ...

# %%
a = dataset.DistanceFromHome
b = dataset.Attrition
stats, p = pearsonr(b,a)

# %%
print(stats, p)
# Out:
# -0.009730141010179659 0.5182860428065224

# %% [markdown]
# ## As r is negative and low, so there is negative low corerelation between Attition and Distance From Home

# %%
print(pearsonr(dataset.Attrition, dataset.YearsAtCompany))
# Out:
# (-0.13439221398997717, 3.16388312248436e-19)

# %% [markdown]
# ## As r is negative, so there is low negative correlation between Attrition and Years At Compant

# %%
dataset.corr()
# Out:
#                               Age  Attrition  DistanceFromHome  Education  \
# Age                      1.000000  -0.159205          0.006963  -0.035706
# Attrition               -0.159205   1.000000         -0.009730  -0.015111
# DistanceFromHome         0.006963  -0.009730          1.000000  -0.008638
# Education               -0.035706  -0.015111         -0.008638   1.000000
# EmployeeCount                 NaN        NaN               NaN        NaN
# EmployeeID               0.008649  -0.004729         -0.001097  -0.009680
# JobLevel                -0.002884  -0.010290         -0.037329   0.045746
# MonthlyIncome           -0.044314  -0.031176         -0.021607   0.006410
# NumCompaniesWorked       0.299243   0.042345         -0.013843  -0.016250
# PercentSalaryHike       -0.033137   0.032533          0.038125  -0.040531
# StandardHours                 NaN        NaN               NaN        NaN
# StockOptionLevel        -0.031753  -0.006839          0.011169   0.001261
# ...
